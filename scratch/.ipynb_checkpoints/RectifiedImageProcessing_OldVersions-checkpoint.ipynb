# %% [markdown]
# # Rectified Image Processing for Thermal Landscapes Project
#  PB 6/6/2022
#
# Reads in rectified multiband thermal images from each site and looks for images that overlap with shapefiles of inside/outside the exclosures. Extracts metrics from thermal images for analysis.

# %%
import rasterio as rio
import numpy as np
import geopandas as gpd
from pathlib import Path
import xarray as xr
import rioxarray as rioxr
from shapely.geometry import Polygon
import matplotlib.pyplot as plt
import pandas as pd
# makes matplotlib plots big
plt.rcParams['figure.figsize'] = [12, 9]
plt.rcParams.update({'font.size': 11})

# %%
# Define inputs
img_dir = Path('/n/davies_lab/Lab/data/products/2020_01-02/MakhEP/raster/thermal/rectifiedimages')
shp_f = Path('./data/in/MakhEP_ExclosurePolygon_AD/Makhohlola_polygon.shp')

# %%
# Load shapefile
shp = gpd.read_file(shp_f)

# %%
# dict of filenames, their bounding polygons, and their pixel xarrays 
# nested in a dict with the shapefile ids as keys
pixel_dict = {'imgf':[], 'boundary_poly':[],
              'pixels_xr':{1:[], 2:[]}, 'N':{1:[], 2:[]}}

# Make list of images to loop through
imglist = [i for i in img_dir.glob('*.tif')]

# for testing,reduce the list size
imglist = imglist[0:5]

# Loop through each image
for i, f in enumerate(imglist):

    # Load image
    img = rioxr.open_rasterio(f,
                              parse_coordinates=True,
                              masked=True)

    # extract the temp band and convert to kelvin
    img_k = (img.sel(band=4)*0.04)

    # filter 0 degree C and below as nans
    img_k = img_k.where(img_k > 273.15)

    # fig, ax = plt.subplots()
    # img_k.plot(ax=ax, cmap='magma')
    # shp.plot(column='id', alpha=0.3, ax=ax, cmap='spring')
    # ax.set_title('')
    # ax.axis('equal')
    
    # Define polygon of bounds of img
    minx, miny, maxx, maxy = img.rio.bounds()

    x_list = [minx, maxx,
              maxx, minx,
              minx]
    y_list = [maxy, maxy,
              miny, miny,
              maxy]

    polygon_geom = Polygon(zip(x_list, y_list))
    clipbox = gpd.GeoDataFrame(index=[0], crs='EPSG:32736', geometry=[polygon_geom])
    
    # If an img overlaps with BOTH shapefile features
    # See: https://geopandas.org/en/stable/docs/user_guide/missing_empty.html
    if np.any(clipbox.intersects(shp)):
        # if np.all(clipbox.intersection(shp).is_empty | clipbox.intersection(shp).isna()):
        
        # Save attributes in dict
        pixel_dict['imgf'].append(f)
        pixel_dict['boundary_poly'].append(clipbox)

        # loop through features in shapefile
        for ID, feature, ax in zip(shp.id, shp.geometry, [ax1, ax2]):

            # Get the intersection, and clip your raster with it
            pixels = img_k.rio.clip(clipbox.intersection(feature), drop=True)

            # Store it in the nested dictionary
            pixel_dict['pixels_xr'][ID].append(pixels)
            
            # Also store number of non-na pixels in each
            n = np.sum(np.isnan(pixels.data.flatten()))
            pixel_dict['N'][ID].append(n)

            # Print stats
            print(f'{ID}: {np.nanmean(pixels.data.flatten())}, {n} pixels')
    
# TBD - You need to check the overlap between the images, 
# perhaps by looping through the polygon boundary files
# Only save pixel_xr for images that do not overlap (that cover new area)
# This is difficult since you need to iteratively check against all images that have been saved thus far
# 6/9/22
# Out:
# WARNING:rasterio._env:CPLE_AppDefined in /n/davies_lab/Lab/data/products/2020_01-02/MakhEP/raster/thermal/rectifiedimages/cam1-000-000098-0.tif: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# /n/home02/pbb/.conda/envs/Halo/lib/python3.8/site-packages/geopandas/base.py:32: UserWarning: The indices of the two GeoSeries are different.
#   warn("The indices of the two GeoSeries are different.")
# WARNING:rasterio._env:CPLE_AppDefined in /n/davies_lab/Lab/data/products/2020_01-02/MakhEP/raster/thermal/rectifiedimages/cam1-000-000215-0.tif: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# /n/home02/pbb/.conda/envs/Halo/lib/python3.8/site-packages/geopandas/base.py:32: UserWarning: The indices of the two GeoSeries are different.
#   warn("The indices of the two GeoSeries are different.")
# WARNING:rasterio._env:CPLE_AppDefined in /n/davies_lab/Lab/data/products/2020_01-02/MakhEP/raster/thermal/rectifiedimages/cam1-000-000152-0.tif: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 1: 307.2403259277344, 18411 pixels
# 2: 307.8953857421875, 66974 pixels
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# /n/home02/pbb/.conda/envs/Halo/lib/python3.8/site-packages/geopandas/base.py:32: UserWarning: The indices of the two GeoSeries are different.
#   warn("The indices of the two GeoSeries are different.")
# WARNING:rasterio._env:CPLE_AppDefined in /n/davies_lab/Lab/data/products/2020_01-02/MakhEP/raster/thermal/rectifiedimages/cam1-000-000051-0.tif: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# 1: 306.5674743652344, 83650 pixels
# 2: 307.1969909667969, 349695 pixels
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# /n/home02/pbb/.conda/envs/Halo/lib/python3.8/site-packages/geopandas/base.py:32: UserWarning: The indices of the two GeoSeries are different.
#   warn("The indices of the two GeoSeries are different.")
# /n/home02/pbb/.conda/envs/Halo/lib/python3.8/site-packages/geopandas/base.py:32: UserWarning: The indices of the two GeoSeries are different.
#   warn("The indices of the two GeoSeries are different.")
# 1: 306.89129638671875, 36732 pixels
# 2: 306.99664306640625, 31157 pixels

# %%
#  playing with merging: https://docs.xarray.dev/en/stable/user-guide/combining.html
#inside_xr = xr.merge(pixel_dict['pixels_xr'][1], compat='override')
# inside_xr = pixel_dict['pixels_xr'][1][0].combine_first(pixel_dict['pixels_xr'][1][1])
# inside_xr = xr.combine_by_coords(pixel_dict['pixels_xr'][1])
# inside_xr.plot()
# fig.tight_layout()

# %%
pixel_dict['pixels_xr'][1]
# Out:
# [<xarray.DataArray (y: 252, x: 176)>
#  array([[      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         ...,
#         [306.8    , 306.68   , 306.52   , ...,       nan,       nan,
#                nan],
#         [306.8    , 306.63998, 306.44   , ...,       nan,       nan,
#                nan],
#         [306.72   , 306.63998, 306.4    , ...,       nan,       nan,
#                nan]], dtype=float32)
#  Coordinates:
#    * y            (y) float64 7.206e+06 7.206e+06 ... 7.205e+06 7.205e+06
#    * x            (x) float64 3.906e+05 3.906e+05 ... 3.907e+05 3.907e+05
#      band         int64 4
#      spatial_ref  int64 0,
#  <xarray.DataArray (y: 545, x: 453)>
#  array([[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]], dtype=float32)
#  Coordinates:
#    * y            (y) float64 7.206e+06 7.206e+06 ... 7.205e+06 7.205e+06
#    * x            (x) float64 3.906e+05 3.906e+05 ... 3.907e+05 3.907e+05
#      band         int64 4
#      spatial_ref  int64 0,
#  <xarray.DataArray (y: 359, x: 272)>
#  array([[306.88   ,       nan,       nan, ...,       nan,       nan,
#                nan],
#         [306.63998, 306.36   , 306.28   , ...,       nan,       nan,
#                nan],
#         [306.8    , 306.52   , 306.24   , ...,       nan,       nan,
#                nan],
#         ...,
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan],
#         [      nan,       nan,       nan, ...,       nan,       nan,
#                nan]], dtype=float32)
#  Coordinates:
#    * y            (y) float64 7.206e+06 7.206e+06 ... 7.205e+06 7.205e+06
#    * x            (x) float64 3.906e+05 3.906e+05 ... 3.907e+05 3.907e+05
#      band         int64 4
#      spatial_ref  int64 0]
